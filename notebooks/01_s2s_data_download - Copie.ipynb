# %% [markdown]
# <div style="width: 100%; text-align: center;">
#     <div style="background-color:#007F00; padding: 0.5rem;">
#         <h1 style="font-weight: bold; font-size: 2.5em; color: black;"> AGRHYMET CENTRE CLIMATIQUE REGIONAL POUR L'AFRIQUE DE L'OUEST ET LE SAHEL</h1>
#    </div>
#
#    <div style="text-align: center;">
#   <img src="https://www.sareco.org/wp-content/uploads/2017/07/plrDvYX1.jpg" width="200">
# </div>

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#FFFFFF ;margin:0;color:#007F00;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Capacity Building in Seasonal Hydrological Forecasting </p>

# %% [markdown]
# <a id="1"></a>
# ### <p style="padding:10px;background-color:#000000 ;margin:0;color:#007F00;font-family:#newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500"> Download Data for WASS2SHydroR </p>

# %%
import pycpt
import packaging
min_version = '2.5.0'
assert packaging.version.parse(pycpt.__version__) >= packaging.version.parse(min_version), f'This notebook requires version {min_version} or higher of the pycpt library, but you have version {pycpt.__version__}. Please close the notebook, update your environment, and load the notebook again. See https://iri-pycpt.github.io/installation/'

import cptdl as dl 
from cptextras import get_colors_bars
import cptextras as ce
import datetime as dt
import numpy as np
from pathlib import Path
import xarray as xr
import pandas as pd
import datetime

import os
import matplotlib.pyplot as plt
import cartopy
import cartopy.crs as ccrs
import numpy as np

# %% [markdown]
# #### Define Case Directory

# %%
os.chdir("D:/CCR_AOS/WASS2SHydroR-training/data")

# %%
case_directory =  Path.home() / "D:/CCR_AOS/WASS2SHydroR-training/data" / "MAM"
case_directory.mkdir(exist_ok=True, parents=True)

# %% [markdown]
# #### Display the list of available predictors

# %%
print([i for i in list(dl.hindcasts.keys()) if "PRCP" in i ])
# Out:
# ['CanCM4i.PRCP', 'CanSIPSv2.PRCP', 'CanSIPSIC3.PRCP', 'CanSIPSIC4.PRCP', 'GEM5NEMO.PRCP', 'CCSM4.PRCP', 'CESM1.PRCP', 'CanCM3.PRCP', 'CanCM4.PRCP', 'FLORB01.PRCP', 'FLORA06.PRCP', 'SPEAR.PRCP', 'GEOSS2S.PRCP', 'CFSv2.PRCP', 'SPSv3p5.PRCP', 'SPSv3p0.PRCP', 'GCFS2p0.PRCP', 'GCFS2p1.PRCP', 'SEAS5.PRCP', 'SEAS51.PRCP', 'SEAS51b.PRCP', 'SEAS51c.PRCP', 'CPS2.PRCP', 'METEOFRANCE7.PRCP', 'METEOFRANCE8.PRCP', 'METEOFRANCE9.PRCP', 'GLOSEA5.PRCP', 'GLOSEA6.PRCP']

# %%
dl.hindcasts
# Out:
# {'CanCM4i.PRCP': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.CanCM4i-IC3/.HINDCAST/.MONTHLY/.prec/SOURCES/.Models/.NMME/.CanCM4i/.FORECAST/.MONTHLY/.prec/S/(1%20Jan%202021)/(1%20Sep%202021)/RANGEEDGES/appendstream/SOURCES/.Models/.NMME/.CanSIPS-IC3/.CanCM4i-IC3/.FORECAST/.MONTHLY/.prec/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{seasonal_target_length(target)}/mul/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanCM4i.T2M': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.CanCM4i-IC3/.HINDCAST/.MONTHLY/.tref/SOURCES/.Models/.NMME/.CanCM4i/.FORECAST/.MONTHLY/.tref/S/(1%20Jan%202021)/(1%20Sep%202021)/RANGEEDGES/appendstream/SOURCES/.Models/.NMME/.CanSIPS-IC3/.CanCM4i-IC3/.FORECAST/.MONTHLY/.tref/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanCM4i.TMAX': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.CanCM4i-IC3/.HINDCAST/.MONTHLY/.tmin/SOURCES/.Models/.NMME/.CanCM4i/.FORECAST/.MONTHLY/.tmin/S/(1%20Jan%202021)/(1%20Sep%202021)/RANGEEDGES/appendstream/SOURCES/.Models/.NMME/.CanSIPS-IC3/.CanCM4i-IC3/.FORECAST/.MONTHLY/.tmin/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanCM4i.TMIN': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.CanCM4i-IC3/.HINDCAST/.MONTHLY/.tmax/SOURCES/.Models/.NMME/.CanCM4i/.FORECAST/.MONTHLY/.tmax/S/(1%20Jan%202021)/(1%20Sep%202021)/RANGEEDGES/appendstream/SOURCES/.Models/.NMME/.CanSIPS-IC3/.CanCM4i-IC3/.FORECAST/.MONTHLY/.tmax/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanCM4i.SST': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.CanCM4i-IC3/.HINDCAST/.MONTHLY/.sst/SOURCES/.Models/.NMME/.CanCM4i/.FORECAST/.MONTHLY/.sst/S/(1%20Jan%202021)/(1%20Sep%202021)/RANGEEDGES/appendstream/SOURCES/.Models/.NMME/.CanSIPS-IC3/.CanCM4i-IC3/.FORECAST/.MONTHLY/.sst/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanCM4i.GPH': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.CanCM4i-IC3/.HINDCAST/.MONTHLY/.hgt/P2/{pressure}/VALUES/SOURCES/.Models/.NMME/.CanCM4i/.FORECAST/.MONTHLY/.hgt/S/(1%20Jan%202021)/(1%20Sep%202021)/RANGEEDGES/P2/{pressure}/VALUES/appendstream/SOURCES/.Models/.NMME/.CanSIPS-IC3/.CanCM4i-IC3/.FORECAST/.MONTHLY/.hgt/P2/{pressure}/VALUES/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanCM4i.PRMSL': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.CanCM4i-IC3/.HINDCAST/.MONTHLY/.prmsl/SOURCES/.Models/.NMME/.CanCM4i/.FORECAST/.MONTHLY/.prmsl/S/(1%20Jan%202021)/(1%20Sep%202021)/RANGEEDGES/appendstream/SOURCES/.Models/.NMME/.CanSIPS-IC3/.CanCM4i-IC3/.FORECAST/.MONTHLY/.prmsl/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanCM4i.UA': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.CanCM4i-IC3/.HINDCAST/.MONTHLY/.ugrd/P/{pressure}/VALUES/SOURCES/.Models/.NMME/.CanCM4i/.FORECAST/.MONTHLY/.ugrd/S/(1%20Jan%202021)/(1%20Sep%202021)/RANGEEDGES/P/{pressure}/VALUES/appendstream/SOURCES/.Models/.NMME/.CanSIPS-IC3/.CanCM4i-IC3/.FORECAST/.MONTHLY/.ugrd/P/{pressure}/VALUES/appendstream/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanCM4i.VA': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.CanCM4i-IC3/.HINDCAST/.MONTHLY/.vgrd/P/{pressure}/VALUES/SOURCES/.Models/.NMME/.CanCM4i/.FORECAST/.MONTHLY/.vgrd/P/{pressure}/VALUES/S/(1%20Jan%202021)/(1%20Sep%202021)/RANGEEDGES/appendstream/SOURCES/.Models/.NMME/.CanSIPS-IC3/.CanCM4i-IC3/.FORECAST/.MONTHLY/.vgrd/P/{pressure}/VALUES/P/{pressure}/VALUES/appendstream/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSv2.PRCP': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPSv2/.HINDCAST/.MONTHLY/.prec/SOURCES/.Models/.NMME/.CanSIPSv2/.FORECAST/.MONTHLY/.prec/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{seasonal_target_length(target)}/mul/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSv2.T2M': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPSv2/.HINDCAST/.MONTHLY/.tref/SOURCES/.Models/.NMME/.CanSIPSv2/.FORECAST/.MONTHLY/.tref/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSv2.TMAX': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPSv2/.HINDCAST/.MONTHLY/.tmax/SOURCES/.Models/.NMME/.CanSIPSv2/.FORECAST/.MONTHLY/.tmax/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSv2.TMIN': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPSv2/.HINDCAST/.MONTHLY/.tmin/SOURCES/.Models/.NMME/.CanSIPSv2/.FORECAST/.MONTHLY/.tmin/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSv2.SST': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPSv2/.HINDCAST/.MONTHLY/.sst/SOURCES/.Models/.NMME/.CanSIPSv2/.FORECAST/.MONTHLY/.sst/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSv2.GPH': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPSv2/.HINDCAST/.MONTHLY/.hgt/SOURCES/.Models/.NMME/.CanSIPSv2/.FORECAST/.MONTHLY/.hgt/appendstream/P2/{pressure}/VALUES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSv2.PRMSL': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPSv2/.HINDCAST/.MONTHLY/.prmsl/SOURCES/.Models/.NMME/.CanSIPSv2/.FORECAST/.MONTHLY/.prmsl/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSv2.UA': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPSv2/.HINDCAST/.MONTHLY/.ugrd/P/{pressure}/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/SOURCES/.Models/.NMME/.CanSIPSv2/.FORECAST/.MONTHLY/.ugrd/P/{pressure}/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSv2.VA': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPSv2/.HINDCAST/.MONTHLY/.ugrd/P/{pressure}/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/SOURCES/.Models/.NMME/.CanSIPSv2/.FORECAST/.MONTHLY/.ugrd/P/{pressure}/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSIC3.PRCP': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.HINDCAST/.MONTHLY/.prec/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{seasonal_target_length(target)}/mul/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSIC3.T2M': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.HINDCAST/.MONTHLY/.tref/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSIC3.TMAX': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.HINDCAST/.MONTHLY/.tmax/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSIC3.TMIN': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.HINDCAST/.MONTHLY/.tmin/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSIC3.SST': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.HINDCAST/.MONTHLY/.sst/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSIC3.GPH': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.HINDCAST/.MONTHLY/.hgt/P2/{pressure}/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSIC3.PRMSL': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.HINDCAST/.MONTHLY/.prmsl/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSIC3.UA': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.HINDCAST/.MONTHLY/.ugrd/P/{pressure}/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSIC3.VA': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.HINDCAST/.MONTHLY/.vgrd/P/{pressure}/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSIC4.PRCP': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC4/.HINDCAST/.MONTHLY/.prec/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{seasonal_target_length(target)}/mul/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSIC4.T2M': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC4/.HINDCAST/.MONTHLY/.tref/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSIC4.TMAX': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC4/.HINDCAST/.MONTHLY/.tmax/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSIC4.TMIN': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC4/.HINDCAST/.MONTHLY/.tmin/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSIC4.SST': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC4/.HINDCAST/.MONTHLY/.sst/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSIC4.GPH': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC4/.HINDCAST/.MONTHLY/.hgt/P/{pressure}/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSIC4.PRMSL': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC4/.HINDCAST/.MONTHLY/.prmsl/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSIC4.UA': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC4/.HINDCAST/.MONTHLY/.ugrd/P/{pressure}/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanSIPSIC4.VA': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC4/.HINDCAST/.MONTHLY/.vgrd/P/{pressure}/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'GEM5NEMO.PRCP': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.GEM5-NEMO/.HINDCAST/.MONTHLY/.prec/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{seasonal_target_length(target)}/mul/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'GEM5NEMO.T2M': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.GEM5-NEMO/.HINDCAST/.MONTHLY/.tref/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'GEM5NEMO.TMAX': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.GEM5-NEMO/.HINDCAST/.MONTHLY/.tmax/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'GEM5NEMO.TMIN': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.GEM5-NEMO/.HINDCAST/.MONTHLY/.tmin/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'GEM5NEMO.SST': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.GEM5-NEMO/.HINDCAST/.MONTHLY/.sst/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'GEM5NEMO.GPH': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.GEM5-NEMO/.HINDCAST/.MONTHLY/.hgt/P2/{pressure}/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'GEM5NEMO.PRMSL': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.GEM5-NEMO/.HINDCAST/.MONTHLY/.prmsl/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'GEM5NEMO.UA': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.GEM5-NEMO/.HINDCAST/.MONTHLY/.ugrd/P/{pressure}/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'GEM5NEMO.VA': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.GEM5-NEMO/.HINDCAST/.MONTHLY/.vgrd/P/{pressure}/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CCSM4.PRCP': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.COLA-RSMAS-CCSM4/.MONTHLY/.prec/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}{seasonal_target_length(target)}/mul/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CCSM4.T2M': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.COLA-RSMAS-CCSM4/.MONTHLY/.tref/Z/2/VALUES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CCSM4.SST': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.COLA-RSMAS-CCSM4/.MONTHLY/.sst/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CCSM4.GPH': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.COLA-RSMAS-CCSM4/.MONTHLY/.gz/P/{pressure}/VALUES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CCSM4.EVAP': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.COLA-RSMAS-CCSM4/.MONTHLY/.evap/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CCSM4.RUNOFF': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.COLA-RSMAS-CCSM4/.MONTHLY/.runoff/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CCSM4.SOILW': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.COLA-RSMAS-CCSM4/.MONTHLY/.soilw/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CCSM4.TMAX': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.COLA-RSMAS-CCSM4/.MONTHLY/.tsmx/Z/2/VALUES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CCSM4.TMIN': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.COLA-RSMAS-CCSM4/.MONTHLY/.tsmn/Z/2/VALUES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CESM1.PRCP': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.COLA-RSMAS-CESM1/.MONTHLY/.prec/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}{seasonal_target_length(target)}/mul/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanCM3.PRCP': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CMC1-CanCM3/.HINDCAST/.MONTHLY/.prec/SOURCES/.Models/.NMME/.CMC1-CanCM3/.FORECAST/.MONTHLY/.prec/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{seasonal_target_length(target)}/mul/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanCM3.T2M': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CMC1-CanCM3/.HINDCAST/.MONTHLY/.tref/SOURCES/.Models/.NMME/.CMC1-CanCM3/.FORECAST/.MONTHLY/.tref/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanCM3.TMAX': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CMC1-CanCM3/.HINDCAST/.MONTHLY/.tmax/SOURCES/.Models/.NMME/.CMC1-CanCM3/.FORECAST/.MONTHLY/.tmax/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanCM3.TMIN': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CMC1-CanCM3/.HINDCAST/.MONTHLY/.tmin/SOURCES/.Models/.NMME/.CMC1-CanCM3/.FORECAST/.MONTHLY/.tmin/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanCM3.SST': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CMC1-CanCM3/.HINDCAST/.MONTHLY/.sst/SOURCES/.Models/.NMME/.CMC1-CanCM3/.FORECAST/.MONTHLY/.sst/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanCM4.PRCP': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CMC2-CanCM4/.HINDCAST/.MONTHLY/.prec/SOURCES/.Models/.NMME/.CMC2-CanCM4/.FORECAST/.MONTHLY/.prec/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{seasonal_target_length(target)}/mul/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanCM4.T2M': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CMC2-CanCM4/.HINDCAST/.MONTHLY/.tref/SOURCES/.Models/.NMME/.CMC2-CanCM4/.FORECAST/.MONTHLY/.tref/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanCM4.TMAX': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CMC2-CanCM4/.HINDCAST/.MONTHLY/.tmax/SOURCES/.Models/.NMME/.CMC2-CanCM4/.FORECAST/.MONTHLY/.tmax/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanCM4.TMIN': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CMC2-CanCM4/.HINDCAST/.MONTHLY/.tmin/SOURCES/.Models/.NMME/.CMC2-CanCM4/.FORECAST/.MONTHLY/.tmin/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'CanCM4.SST': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CMC2-CanCM4/.HINDCAST/.MONTHLY/.sst/SOURCES/.Models/.NMME/.CMC2-CanCM4/.FORECAST/.MONTHLY/.sst/appendstream/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/{'%5BM%5D/average/' if ensemblemean else ''}Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'FLORB01.PRCP': "https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.GFDL-CM2p5-FLOR-B01/.MONTHLY/.prec/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}{seasonal_target_length(target)}/mul/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
# ...
#  'METEOFRANCE8.T2M': "https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.Meteo_France/.System8/.hindcast/.t2m/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'METEOFRANCE8.GPH': "https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.Meteo_France/.System8/.hindcast/.z/P/{pressure}/VALUES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'METEOFRANCE8.SST': "https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.Meteo_France/.System8/.hindcast/.sst/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'METEOFRANCE8.UA': "https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.Meteo_France/.System8/.hindcast/.ua/P/{pressure}/VALUES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'METEOFRANCE8.VA': "https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.Meteo_France/.System8/.hindcast/.va/P/{pressure}/VALUES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'METEOFRANCE9.PRCP': "https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.Meteo_France/.System9/.hindcast/.prcp/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/{seasonal_target_length(target)}//units/(days)/def/%3Ac/mul/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'METEOFRANCE9.T2M': "https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.Meteo_France/.System9/.hindcast/.t2m/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'METEOFRANCE9.GPH': "https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.Meteo_France/.System9/.hindcast/.z/P/{pressure}/VALUES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'METEOFRANCE9.SST': "https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.Meteo_France/.System9/.hindcast/.sst/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'METEOFRANCE9.UA': "https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.Meteo_France/.System9/.hindcast/.ua/P/{pressure}/VALUES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'METEOFRANCE9.VA': "https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.Meteo_France/.System9/.hindcast/.va/P/{pressure}/VALUES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'GLOSEA5.PRCP': "https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.UKMO/.GloSea5-GC2/.System15/.hindcast/.prcp/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/{seasonal_target_length(target)}//units/(days)/def/%3Ac/mul/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'GLOSEA5.T2M': "https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.UKMO/.GloSea5-GC2/.System15/.hindcast/.t2m/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'GLOSEA5.GPH': "https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.UKMO/.GloSea5-GC2/.System15/.hindcast/.z/P/{pressure}/VALUES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'GLOSEA5.SST': "https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.UKMO/.GloSea5-GC2/.System15/.hindcast/.sst/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'GLOSEA5.UA': "https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.UKMO/.GloSea5-GC2/.System15/.hindcast/.ua/P/{pressure}/VALUES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'GLOSEA5.VA': "https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.UKMO/.GloSea5-GC2/.System15/.hindcast/.va/P/{pressure}/VALUES/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'GLOSEA6.PRCP': "https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.UKMO/.GloSea6-GC2/.System600/.hindcast/.prcp/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/{seasonal_target_length(target)}//units/(days)/def/%3Ac/mul/-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'GLOSEA6.T2M': "https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.UKMO/.GloSea6-GC2/.System600/.hindcast/.t2m/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'GLOSEA6.SLP': "https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.UKMO/.GloSea6-GC2/.System600/.hindcast/.slp/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'GLOSEA6.SST': "https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.UKMO/.GloSea6-GC2/.System600/.hindcast/.sst/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'GLOSEA6.UA': "https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.UKMO/.GloSea6-GC2/.System600/.hindcast/.ua/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}",
#  'GLOSEA6.VA': "https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.UKMO/.GloSea6-GC2/.System600/.hindcast/.va/S/%280000%201%20{threeletters[fdate.month]}%20{first_year}-{final_year}%29/VALUES/L/{lead_low}/{lead_high}/RANGEEDGES/%5BL%5D//keepgrids/average/Y/{predictor_extent['south']}/{predictor_extent['north']}/RANGEEDGES/X/{predictor_extent['west']}/{predictor_extent['east']}/RANGEEDGES/{'%5BM%5D/average/' if ensemblemean else ''}-999/setmissing_value/{'%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv' if filetype == 'cptv10.tsv' and ensemblemean else '%5BX/Y%5D%5BL/S/add/M%5D/cptv10.tsv' if filetype =='cptv10.tsv' and not ensemblemean else filetype}"}

# %% [markdown]
# #### Parameters - This cell defines the parameters of your analysis

# %%
MOS = 'PCR' # must be one of 'CCA', 'PCR'
local_predictand_file = None
predictor_names = [ 'CCSM4.SST', 
                   'CFSv2.SST', 'SEAS51b.SST',
                   'METEOFRANCE8.SST',  
                   'GEM5NEMO.SST',  'SPSv3p5.SST']

predictor_names = [i for i in list(dl.hindcasts.keys()) if "PRCP" in i ]
# Gridded predictand data from the PyCPT catalog.
# Run dl.observations.keys() to see all predefined options.
predictand_name = 'UCSB.PRCP'

# Using a a predictand dataset from the IRI Data Library that
# is not predefined in the PyCPT catalog.
# This dataset happens to be a weather station data product.
# dl.observations['GHCN.PRCP'] = "http://iridl.ldeo.columbia.edu/SOURCES/.NOAA/.NCDC/.GHCN/.v2beta/IWMO/grid%3A//name/(IWMO)/def//units/(ids)/def//long_name/(Station)/def/1/1/20590/%3Agrid/replaceGRID/lon/{predictand_extent['west']}/{predictand_extent['east']}/masknotrange/SELECT/lat/{predictand_extent['south']}/{predictand_extent['north']}/masknotrange/SELECT/dup/a%3A/.lat//name//Y/def/%3Aa%3A/.lon//name//X/def/%3Aa%3A/.Name/%3Aa%3A/.prcp/T/({target}%20{first_year}-{final_year})/seasonalAverage/-999/setmissing_value/%3Aa/%7BY/X/Name/prcp%7Dds/{'%5BIWMO%5D%5BT%5D/' + filetype if filetype == 'cptv10.tsv' else 'data.nc'}"
# predictand_name = 'GHCN.PRCP'

# When using predictand data from the Data Library, set this to None
local_predictand_file = None
# To read predictand data from a local file instead of the Data Library,
# set local_predictand_file to the full pathname of the file. e.g.
# local_predictand_file = "/home/aaron/src/pycpt_notebooks/obs_PRCP_Oct-Dec.tsv"
#
# The file should be formatted according to the following guidelines:
# https://cpthelp.iri.columbia.edu/CPT_use_input_gridded.html
# https://cpthelp.iri.columbia.edu/CPT_use_input_stations.html


download_args = { 
    # 'fdate':
    #   The initialization date of the model forecasts / hindcasts.
    #   This field is defined by a python datetime.datetime object,
    #   for example: dt.datetime(2022, 5, 1) # YYYY, MM, DD as integers
    #   The year field is only used for forecasts, otherwise ignored.
    #   The day field is only used in subseasonal forecasts, otherwise ignored.
    #   The month field is an integer representing a month - ie, May=5.
    'fdate':  dt.datetime(2026, 2, 1),

    # 'target_first_year':
    #   The year of the earliest hindcast target season to use for training. **NOT ALL MODELS HAVE ALL YEARS**.
    #   Double check that your model has hindcast data for all years in [first_year, final_year].
    #   Note that the year of a season is the year of its midpoint, e.g. the season from
    #   Dec 1999 to Feb 2000 has its midpoint in mid-Jan 2000, so we call it the 2000 season.
    #   This field is defined by a python integer representing a year, e.g. 1993.
    'first_year': 1981,

    # 'target_final_year':
    #   Double check that your model has hindcast data for all years in [first_year, final_year].
    #   This field is defined by a python integer representing a year, e.g. 2016.
    'final_year': 2025,

    # 'target': 
    #   Mmm-Mmm indicating the months included in the target period of the forecast. 
    #   This field is defined by a python string, with two three-letter month name abbreviations 
    #   whose first letters are capitalized, and all other letters are lowercase
    #   and who are separated by a dash character. 
    #   For example, if you wanted a JJA target period, you would use 'Jun-Aug'.
    'target': 'Mar-May',

    # 'predictor_extent':
    #   The geographic bounding box of the climate model data you want to download.
    #   This field is defined by a python dictionary with the keys "north", "south",
    #   "east", and "west", each of which maps to a python integer representing the 
    #   edge of a bounding box. i.e., "north" will be the northernmost boundary,
    #   "south" the southernmost boundary.
    #   Example: {"north": 90, "south": -90, "east": 0, "west": 180}
    'predictor_extent_': {
         #'east':  180,
        # 'west': -180,  
         #'north': 90,  
        # 'south': -90, 

         'east': 30,
        'west': -27,  
         'north': 34,  
         'south': 0, 
    }, 

    'predictor_extent': {
    'east': 20,
    'west': -60,
    'north': 25,
    'south': -25,
},


    # 'predictand_extent':
    #   The geographic bounding box of the observation data you want to download.
    #   This field is defined by a python dictionary with the keys "north", "south",
    #   "east", and "west", each of which maps to a python integer representing the 
    #   edge of a bounding box. i.e., "north" will be the northernmost boundary,
    #   "south" the southernmost boundary.
    #   Example: {"north": 90, "south": -90, "east": 0, "west": 180}
    'predictand_extent': {
        'east': 28,
        'west': -18,  
        'north': 29,  
        'south': 0, 
    },
}

# %%
predictor_names = [ 'CCSM4.SST', 
                   'CFSv2.SST', 'SEAS51b.SST',
                   'METEOFRANCE8.SST',  
                   'GEM5NEMO.SST',  'SPSv3p5.SST']

predictand_name = 'UCSB.PRCP'

download_args = { 
    # 'fdate':
    #   The initialization date of the model forecasts / hindcasts.
    #   This field is defined by a python datetime.datetime object,
    #   for example: dt.datetime(2022, 5, 1) # YYYY, MM, DD as integers
    #   The year field is only used for forecasts, otherwise ignored.
    #   The day field is only used in subseasonal forecasts, otherwise ignored.
    #   The month field is an integer representing a month - ie, May=5.
    'fdate':  dt.datetime(2026, 2, 1),

    # 'target_first_year':
    #   The year of the earliest hindcast target season to use for training. **NOT ALL MODELS HAVE ALL YEARS**.
    #   Double check that your model has hindcast data for all years in [first_year, final_year].
    #   Note that the year of a season is the year of its midpoint, e.g. the season from
    #   Dec 1999 to Feb 2000 has its midpoint in mid-Jan 2000, so we call it the 2000 season.
    #   This field is defined by a python integer representing a year, e.g. 1993.
    'first_year': 1981,

    # 'target_final_year':
    #   Double check that your model has hindcast data for all years in [first_year, final_year].
    #   This field is defined by a python integer representing a year, e.g. 2016.
    'final_year': 2025,

    # 'target': 
    #   Mmm-Mmm indicating the months included in the target period of the forecast. 
    #   This field is defined by a python string, with two three-letter month name abbreviations 
    #   whose first letters are capitalized, and all other letters are lowercase
    #   and who are separated by a dash character. 
    #   For example, if you wanted a JJA target period, you would use 'Jun-Aug'.
    'target': 'Mar-May',

    # 'predictor_extent':
    #   The geographic bounding box of the climate model data you want to download.
    #   This field is defined by a python dictionary with the keys "north", "south",
    #   "east", and "west", each of which maps to a python integer representing the 
    #   edge of a bounding box. i.e., "north" will be the northernmost boundary,
    #   "south" the southernmost boundary.
    #   Example: {"north": 90, "south": -90, "east": 0, "west": 180}
    'predictor_extent_': {


         'east': 30,
        'west': -27,  
         'north': 34,  
         'south': 0, 
    }, 

    'predictor_extent': {
    'east': 20,
    'west': -60,
    'north': 25,
    'south': -25,
},


    # 'predictand_extent':
    #   The geographic bounding box of the observation data you want to download.
    #   This field is defined by a python dictionary with the keys "north", "south",
    #   "east", and "west", each of which maps to a python integer representing the 
    #   edge of a bounding box. i.e., "north" will be the northernmost boundary,
    #   "south" the southernmost boundary.
    #   Example: {"north": 90, "south": -90, "east": 0, "west": 180}
    'predictand_extent': {
        'east': 28,
        'west': -18,  
        'north': 29,  
        'south': 0, 
    },
}

# %% [markdown]
# ### Show the working directory

# %%
domain_dir = pycpt.setup(case_directory, download_args["predictor_extent"])
# Out:
# Input data will be saved in D:\CCR_AOS\WASS2SHydroR-training\data\MAM\-60W-20E_to_-25S-25N\data
# Figures will be saved in D:\CCR_AOS\WASS2SHydroR-training\data\MAM\-60W-20E_to_-25S-25N\figures
# Output will be saved in D:\CCR_AOS\WASS2SHydroR-training\data\MAM\-60W-20E_to_-25S-25N\output

# %% [markdown]
# ### Plot the predictors and the predictants extents

# %%
e=download_args["predictor_extent"]['east']
w=download_args["predictor_extent"]['west']
n=download_args["predictor_extent"]['north']
s=download_args["predictor_extent"]['south']
e1=download_args["predictand_extent"]['east']
w1=download_args["predictand_extent"]['west']
n1=download_args["predictand_extent"]['north']
s1=download_args["predictand_extent"]['south']
domainFolder = str(w) + "W-" + str(e) + "E" + "_to_" + str(s) + "S-" + str(n) + "N"
dataDir = domain_dir / "data"

# %%
pycpt.plot_domains(download_args['predictor_extent'], download_args['predictand_extent'])

# %% [markdown]
# ## Download Observations, Hindcasts, and Forecasts from IRI Data Library

# %% [markdown]
# Set **force_download** = False to avoid re-downloading files you have already downloaded. Note: if you have changed anything in download_args since the data were last downloaded, you must set force_download = True, otherwise you will use the old data instead of the new.

# %%
force_download = False

# %%
domain_dir
# Out:
# WindowsPath('D:/CCR_AOS/WASS2SHydroR-training/data/MAM/-60W-20E_to_-25S-25N')

# %%
Y, hindcast_data, forecast_data = pycpt.download_data(predictand_name, 
                                                      local_predictand_file, 
                                                      predictor_names, 
                                                      download_args, 
                                                      domain_dir, force_download)
# Out:
# Downloading CanCM4i.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanCM4i/.FORECAST/.MONTHLY/.prec/S/first/(1%20Sep%202021)/RANGEEDGES/SOURCES/.Models/.NMME/.CanSIPS-IC3/.CanCM4i-IC3/.FORECAST/.MONTHLY/.prec/appendstream/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/%5BM%5D/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# Not found. Continuing without it.
#
# Downloading CanSIPSv2.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPSv2/.HINDCAST/.MONTHLY/.prec/SOURCES/.Models/.NMME/.CanSIPSv2/.FORECAST/.MONTHLY/.prec/appendstream/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/%5BM%5D/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# Not found. Continuing without it.
#
# Downloading CanSIPSIC3.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.FORECAST/.MONTHLY/.prec/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/%5BM%5D/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# Not found. Continuing without it.
#
# Downloading CanSIPSIC4.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC4/.FORECAST/.MONTHLY/.prec/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/%5BM%5D/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (59 KB) 0:00:05.164127
#
# Downloading GEM5NEMO.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.GEM5-NEMO/.FORECAST/.MONTHLY/.prec/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/%5BM%5D/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# Not found. Continuing without it.
#
# Downloading CCSM4.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.COLA-RSMAS-CCSM4/.MONTHLY/.prec/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (59 KB) 0:00:00.777780
#
# Downloading CESM1.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.COLA-RSMAS-CESM1/.MONTHLY/.prec/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (59 KB) 0:00:00.320130
#
# Downloading CanCM3.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CMC1-CanCM3/.HINDCAST/.MONTHLY/.prec/SOURCES/.Models/.NMME/.CMC1-CanCM3/.FORECAST/.MONTHLY/.prec/appendstream/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/%5BM%5D/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# Not found. Continuing without it.
#
# Downloading CanCM4.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CMC2-CanCM4/.HINDCAST/.MONTHLY/.prec/SOURCES/.Models/.NMME/.CMC2-CanCM4/.FORECAST/.MONTHLY/.prec/appendstream/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/%5BM%5D/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# Not found. Continuing without it.
#
# Downloading FLORB01.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.GFDL-CM2p5-FLOR-B01/.MONTHLY/.prec/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# Not found. Continuing without it.
#
# Downloading FLORA06.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.GFDL-CM2p5-FLOR-A06/.MONTHLY/.prec/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# Not found. Continuing without it.
#
# Downloading SPEAR.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.GFDL-SPEAR/.FORECAST/.MONTHLY/.prec/%5BM%5D/average/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# Not found. Continuing without it.
#
# Downloading GEOSS2S.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.NASA-GEOSS2S/.HINDCAST/.MONTHLY/.prec/%5BM%5D/average/SOURCES/.Models/.NMME/.NASA-GEOSS2S/.FORECAST/.MONTHLY/.prec/%5BM%5D/average/appendstream/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (59 KB) 0:00:00.326664
#
# Downloading CFSv2.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.NCEP-CFSv2/.HINDCAST/.PENTAD_SAMPLES_FULL/.prec/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (59 KB) 0:00:00.334212
#
# Downloading SPSv3p5.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.CMCC/.SPSv3p5/.forecast/.prcp/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# Not found. Continuing without it.
#
# Downloading SPSv3p0.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.CMCC/.SPSv3/.forecast/.prcp/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# Not found. Continuing without it.
#
# Downloading GCFS2p0.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.DWD/.GCFS2p0/.forecast/.prcp/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# Not found. Continuing without it.
#
# Downloading GCFS2p1.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.DWD/.GCFS2p1/.forecast/.prcp/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# Not found. Continuing without it.
#
# Downloading SEAS5.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.ECMWF/.SEAS5/.forecast/.prcp/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# Not found. Continuing without it.
#
# Downloading SEAS51.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.ECMWF/.SEAS51/.forecast/.prcp/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# C:\Users\ARSENE\anaconda3\envs\CForecast\Lib\site-packages\pycpt\notebook.py:303: UserWarning: SEAS51.PRCP is deprecated. New configurations should use SEAS51c.PRCP instead. See https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.ECMWF/.dataset_documentation.html .
#   warnings.warn(
# DOWNLOADING: [*************************] (59 KB) 0:00:00.829651
#
# Downloading SEAS51b.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.ECMWF/.SEAS51_Y180/.forecast/.prcp/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# C:\Users\ARSENE\anaconda3\envs\CForecast\Lib\site-packages\pycpt\notebook.py:303: UserWarning: SEAS51b.PRCP is deprecated. New configurations should use SEAS51c.PRCP instead. See https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.ECMWF/.dataset_documentation.html .
#   warnings.warn(
# DOWNLOADING: [*************************] (58 KB) 0:00:00.644047
#
# Downloading SEAS51c.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.ECMWF/.SEAS51_iri2/.appended/.prcp/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (57 KB) 0:00:00.343664
#
# Downloading CPS2.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.JMA/.CPS2/.forecast/.prec/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# Not found. Continuing without it.
#
# Downloading METEOFRANCE7.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.Meteo_France/.System7/.forecast/.prcp/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# Not found. Continuing without it.
#
# Downloading METEOFRANCE8.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.Meteo_France/.System8/.forecast/.prcp/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# Not found. Continuing without it.
#
# Downloading METEOFRANCE9.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.Meteo_France/.System9/.forecast/.prcp/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# Not found. Continuing without it.
#
# Downloading GLOSEA5.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.UKMO/.GloSea5-GC2/.System15/.forecast/.prcp/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# Not found. Continuing without it.
#
# Downloading GLOSEA6.PRCP_f2026
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.UKMO/.GloSea6-GC2/.System600/.forecast/.prcp/S/%280000%201%20Feb%202026%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# Not found. Continuing without it.
#
# Downloading UCSB.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.UCSB/.CHIRPS/.v2p0/.daily-improved/.global/.0p25/.prcp/92/mul/T/(1%20Jan%201981)/(31%20Dec%202025)/RANGE/T/%28Mar-May%201981-2025%29/seasonalAverage/Y/%280%29/%2829%29/RANGEEDGES/X/%28-18%29/%2828%29/RANGEEDGES/-999/setmissing_value/%5BX/Y%5D%5BT%5Dcptv10.tsv
# DOWNLOADING: [*************************] (13640 KB) 0:02:34.779748
#
# Downloading CanCM4i.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.CanCM4i-IC3/.HINDCAST/.MONTHLY/.prec/SOURCES/.Models/.NMME/.CanCM4i/.FORECAST/.MONTHLY/.prec/S/(1%20Jan%202021)/(1%20Sep%202021)/RANGEEDGES/appendstream/SOURCES/.Models/.NMME/.CanSIPS-IC3/.CanCM4i-IC3/.FORECAST/.MONTHLY/.prec/appendstream/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/%5BM%5D/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# C:\Users\ARSENE\anaconda3\envs\CForecast\Lib\site-packages\pycpt\notebook.py:303: UserWarning: SEAS51.PRCP is deprecated. New configurations should use SEAS51c.PRCP instead. See https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.ECMWF/.dataset_documentation.html .
#   warnings.warn(
# C:\Users\ARSENE\anaconda3\envs\CForecast\Lib\site-packages\pycpt\notebook.py:303: UserWarning: SEAS51b.PRCP is deprecated. New configurations should use SEAS51c.PRCP instead. See https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.ECMWF/.dataset_documentation.html .
#   warnings.warn(
# DOWNLOADING: [*************************] (2601 KB) 0:00:15.418004
#
# Downloading CanSIPSv2.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPSv2/.HINDCAST/.MONTHLY/.prec/SOURCES/.Models/.NMME/.CanSIPSv2/.FORECAST/.MONTHLY/.prec/appendstream/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/%5BM%5D/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (2429 KB) 0:00:23.501455
#
# Downloading CanSIPSIC3.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.HINDCAST/.MONTHLY/.prec/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/%5BM%5D/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (2423 KB) 0:00:16.045746
#
# Downloading CanSIPSIC4.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC4/.HINDCAST/.MONTHLY/.prec/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/%5BM%5D/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (2073 KB) 0:03:55.827117
#
# Downloading GEM5NEMO.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CanSIPS-IC3/.GEM5-NEMO/.HINDCAST/.MONTHLY/.prec/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/%5BM%5D/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (2428 KB) 0:00:11.051513
#
# Downloading CCSM4.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.COLA-RSMAS-CCSM4/.MONTHLY/.prec/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (2593 KB) 0:00:16.287199
#
# Downloading CESM1.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.COLA-RSMAS-CESM1/.MONTHLY/.prec/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (2607 KB) 0:00:15.881058
#
# Downloading CanCM3.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CMC1-CanCM3/.HINDCAST/.MONTHLY/.prec/SOURCES/.Models/.NMME/.CMC1-CanCM3/.FORECAST/.MONTHLY/.prec/appendstream/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/%5BM%5D/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (2310 KB) 0:00:18.829458
#
# Downloading CanCM4.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.CMC2-CanCM4/.HINDCAST/.MONTHLY/.prec/SOURCES/.Models/.NMME/.CMC2-CanCM4/.FORECAST/.MONTHLY/.prec/appendstream/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/%5BM%5D/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (2310 KB) 0:00:20.016597
#
# Downloading FLORB01.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.GFDL-CM2p5-FLOR-B01/.MONTHLY/.prec/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (2370 KB) 0:00:17.825415
#
# Downloading FLORA06.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.GFDL-CM2p5-FLOR-A06/.MONTHLY/.prec/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (2370 KB) 0:00:21.016109
#
# Downloading SPEAR.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.GFDL-SPEAR/.HINDCAST/.MONTHLY/.prec/%5BM%5D/average/S/first/(1%20Nov%202020)/RANGEEDGES/SOURCES/.Models/.NMME/.GFDL-SPEAR/.FORECAST/.MONTHLY/.prec/%5BM%5D/average/appendstream/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (2063 KB) 0:00:22.131206
#
# Downloading GEOSS2S.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.NASA-GEOSS2S/.HINDCAST/.MONTHLY/.prec/%5BM%5D/average/SOURCES/.Models/.NMME/.NASA-GEOSS2S/.FORECAST/.MONTHLY/.prec/%5BM%5D/average/appendstream/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (2665 KB) 0:00:11.241586
#
# Downloading CFSv2.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.NCEP-CFSv2/.HINDCAST/.PENTAD_SAMPLES_FULL/.prec/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (2607 KB) 0:00:11.313480
#
# Downloading SPSv3p5.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.CMCC/.SPSv3p5/.hindcast/.prcp/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (1377 KB) 0:00:12.112446
#
# Downloading SPSv3p0.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.CMCC/.SPSv3/.hindcast/.prcp/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (1377 KB) 0:00:10.521523
#
# Downloading GCFS2p0.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.DWD/.GCFS2p0/.hindcast/.prcp/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (1377 KB) 0:00:11.754689
#
# Downloading GCFS2p1.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.DWD/.GCFS2p1/.hindcast/.prcp/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (1549 KB) 0:00:09.999407
#
# Downloading SEAS5.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.ECMWF/.SEAS5/.hindcast/.prcp/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (2133 KB) 0:00:09.000052
#
# Downloading SEAS51.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.ECMWF/.SEAS51/.hindcast/.prcp/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (2133 KB) 0:00:09.170772
#
# Downloading SEAS51b.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.ECMWF/.SEAS51_Y180/.hindcast/.prcp/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (2090 KB) 0:00:06.176115
#
# Downloading SEAS51c.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.ECMWF/.SEAS51_iri2/.appended/.prcp/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (2581 KB) 0:00:08.111890
#
# Downloading CPS2.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.JMA/.CPS2/.hindcast/.prec/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (246 KB) 0:00:01.033000
#
# Downloading METEOFRANCE7.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.Meteo_France/.System7/.hindcast/.prcp/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (1369 KB) 0:00:09.016974
#
# Downloading METEOFRANCE8.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.Meteo_France/.System8/.hindcast/.prcp/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (1491 KB) 0:00:05.728891
#
# Downloading METEOFRANCE9.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.Meteo_France/.System9/.hindcast/.prcp/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (1835 KB) 0:00:08.204880
#
# Downloading GLOSEA5.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.UKMO/.GloSea5-GC2/.System15/.hindcast/.prcp/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (1377 KB) 0:00:05.364259
#
# Downloading GLOSEA6.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.EU/.Copernicus/.CDS/.C3S/.UKMO/.GloSea6-GC2/.System600/.hindcast/.prcp/S/%280000%201%20Feb%201981-2025%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-25/25/RANGEEDGES/X/-60/20/RANGEEDGES/%5BM%5D/average/c%3A/1000/(mm%20m-1)/%3Ac/mul/c%3A/86400/(s%20day-1)/%3Ac/mul/c%3A/92//units/(days)/def/%3Ac/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
# DOWNLOADING: [*************************] (1377 KB) 0:00:06.021295

# %%
pycpt.summarize_available_years(predictor_names, predictand_name, download_args, Y, hindcast_data, forecast_data)
# Out:
# <H1>Training data</H1>
# Observations were retrieved for all years of the training period.
# Some hindcasts were missing for some years of the training period. Missing hindcasts are noted below. If you continue, missing hindcasts will be replaced with the missing model's climatology.
# <style type="text/css">
# #T_7dce8_row0_col0, #T_7dce8_row0_col1, #T_7dce8_row0_col2, #T_7dce8_row0_col3, #T_7dce8_row0_col5, #T_7dce8_row0_col7, #T_7dce8_row0_col8, #T_7dce8_row0_col9, #T_7dce8_row0_col10, #T_7dce8_row0_col13, #T_7dce8_row0_col19, #T_7dce8_row0_col20, #T_7dce8_row0_col21, #T_7dce8_row0_col22, #T_7dce8_row1_col0, #T_7dce8_row1_col1, #T_7dce8_row1_col2, #T_7dce8_row1_col3, #T_7dce8_row1_col5, #T_7dce8_row1_col6, #T_7dce8_row1_col7, #T_7dce8_row1_col8, #T_7dce8_row1_col9, #T_7dce8_row1_col10, #T_7dce8_row1_col13, #T_7dce8_row1_col14, #T_7dce8_row1_col19, #T_7dce8_row1_col20, #T_7dce8_row1_col21, #T_7dce8_row1_col22, #T_7dce8_row2_col0, #T_7dce8_row2_col1, #T_7dce8_row2_col2, #T_7dce8_row2_col3, #T_7dce8_row2_col5, #T_7dce8_row2_col6, #T_7dce8_row2_col7, #T_7dce8_row2_col8, #T_7dce8_row2_col9, #T_7dce8_row2_col10, #T_7dce8_row2_col13, #T_7dce8_row2_col14, #T_7dce8_row2_col19, #T_7dce8_row2_col20, #T_7dce8_row2_col21, #T_7dce8_row2_col22, #T_7dce8_row3_col0, #T_7dce8_row3_col1, #T_7dce8_row3_col2, #T_7dce8_row3_col3, #T_7dce8_row3_col5, #T_7dce8_row3_col6, #T_7dce8_row3_col7, #T_7dce8_row3_col8, #T_7dce8_row3_col9, #T_7dce8_row3_col10, #T_7dce8_row3_col13, #T_7dce8_row3_col14, #T_7dce8_row3_col19, #T_7dce8_row3_col20, #T_7dce8_row3_col21, #T_7dce8_row3_col22, #T_7dce8_row4_col0, #T_7dce8_row4_col1, #T_7dce8_row4_col2, #T_7dce8_row4_col3, #T_7dce8_row4_col5, #T_7dce8_row4_col6, #T_7dce8_row4_col7, #T_7dce8_row4_col8, #T_7dce8_row4_col9, #T_7dce8_row4_col10, #T_7dce8_row4_col13, #T_7dce8_row4_col14, #T_7dce8_row4_col19, #T_7dce8_row4_col20, #T_7dce8_row4_col21, #T_7dce8_row4_col22, #T_7dce8_row5_col0, #T_7dce8_row5_col1, #T_7dce8_row5_col2, #T_7dce8_row5_col3, #T_7dce8_row5_col5, #T_7dce8_row5_col6, #T_7dce8_row5_col7, #T_7dce8_row5_col8, #T_7dce8_row5_col9, #T_7dce8_row5_col10, #T_7dce8_row5_col13, #T_7dce8_row5_col14, #T_7dce8_row5_col19, #T_7dce8_row5_col20, #T_7dce8_row5_col21, #T_7dce8_row5_col22, #T_7dce8_row6_col0, #T_7dce8_row6_col1, #T_7dce8_row6_col2, #T_7dce8_row6_col3, #T_7dce8_row6_col5, #T_7dce8_row6_col6, #T_7dce8_row6_col7, #T_7dce8_row6_col8, #T_7dce8_row6_col9, #T_7dce8_row6_col10, #T_7dce8_row6_col13, #T_7dce8_row6_col14, #T_7dce8_row6_col19, #T_7dce8_row6_col20, #T_7dce8_row6_col21, #T_7dce8_row6_col22, #T_7dce8_row7_col0, #T_7dce8_row7_col1, #T_7dce8_row7_col2, #T_7dce8_row7_col3, #T_7dce8_row7_col5, #T_7dce8_row7_col6, #T_7dce8_row7_col7, #T_7dce8_row7_col8, #T_7dce8_row7_col9, #T_7dce8_row7_col10, #T_7dce8_row7_col13, #T_7dce8_row7_col14, #T_7dce8_row7_col19, #T_7dce8_row7_col20, #T_7dce8_row7_col21, #T_7dce8_row7_col22, #T_7dce8_row8_col0, #T_7dce8_row8_col1, #T_7dce8_row8_col2, #T_7dce8_row8_col3, #T_7dce8_row8_col5, #T_7dce8_row8_col6, #T_7dce8_row8_col7, #T_7dce8_row8_col8, #T_7dce8_row8_col9, #T_7dce8_row8_col10, #T_7dce8_row8_col13, #T_7dce8_row8_col14, #T_7dce8_row8_col19, #T_7dce8_row8_col20, #T_7dce8_row8_col21, #T_7dce8_row8_col22, #T_7dce8_row9_col0, #T_7dce8_row9_col1, #T_7dce8_row9_col2, #T_7dce8_row9_col3, #T_7dce8_row9_col4, #T_7dce8_row9_col5, #T_7dce8_row9_col6, #T_7dce8_row9_col7, #T_7dce8_row9_col8, #T_7dce8_row9_col9, #T_7dce8_row9_col10, #T_7dce8_row9_col13, #T_7dce8_row9_col14, #T_7dce8_row9_col19, #T_7dce8_row9_col20, #T_7dce8_row9_col21, #T_7dce8_row9_col22, #T_7dce8_row10_col0, #T_7dce8_row10_col1, #T_7dce8_row10_col2, #T_7dce8_row10_col3, #T_7dce8_row10_col4, #T_7dce8_row10_col5, #T_7dce8_row10_col6, #T_7dce8_row10_col7, #T_7dce8_row10_col8, #T_7dce8_row10_col9, #T_7dce8_row10_col10, #T_7dce8_row10_col11, #T_7dce8_row10_col12, #T_7dce8_row10_col13, #T_7dce8_row10_col14, #T_7dce8_row10_col19, #T_7dce8_row10_col20, #T_7dce8_row10_col21, #T_7dce8_row10_col22, #T_7dce8_row11_col0, #T_7dce8_row11_col1, #T_7dce8_row11_col2, #T_7dce8_row11_col3, #T_7dce8_row11_col4, #T_7dce8_row11_col5, #T_7dce8_row11_col6, #T_7dce8_row11_col7, #T_7dce8_row11_col8, #T_7dce8_row11_col9, #T_7dce8_row11_col10, #T_7dce8_row11_col11, #T_7dce8_row11_col12, #T_7dce8_row11_col13, #T_7dce8_row11_col14, #T_7dce8_row11_col19, # ...
# <H1>Forecast data</H1>
# Some forecasts were not available and will be replaced with the missing model's climatology.
# <style type="text/css">
# #T_c1682_row0_col0, #T_c1682_row0_col1, #T_c1682_row0_col2, #T_c1682_row0_col4, #T_c1682_row0_col6, #T_c1682_row0_col7, #T_c1682_row0_col8, #T_c1682_row0_col9, #T_c1682_row0_col10, #T_c1682_row0_col11, #T_c1682_row0_col14, #T_c1682_row0_col15, #T_c1682_row0_col16, #T_c1682_row0_col17, #T_c1682_row0_col18, #T_c1682_row0_col22, #T_c1682_row0_col23, #T_c1682_row0_col24, #T_c1682_row0_col25, #T_c1682_row0_col26, #T_c1682_row0_col27 {
#   background: yellow;
#   text-align: center;
# }
# #T_c1682_row0_col3, #T_c1682_row0_col5, #T_c1682_row0_col12, #T_c1682_row0_col13, #T_c1682_row0_col19, #T_c1682_row0_col20, #T_c1682_row0_col21 {
#   text-align: center;
# }
# </style>
# <table id="T_c1682">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1682_level0_col0" class="col_heading level0 col0" >CanCM4i.SST</th>
#       <th id="T_c1682_level0_col1" class="col_heading level0 col1" >CanSIPSv2.SST</th>
#       <th id="T_c1682_level0_col2" class="col_heading level0 col2" >CanSIPSIC3.SST</th>
#       <th id="T_c1682_level0_col3" class="col_heading level0 col3" >CanSIPSIC4.SST</th>
#       <th id="T_c1682_level0_col4" class="col_heading level0 col4" >GEM5NEMO.SST</th>
#       <th id="T_c1682_level0_col5" class="col_heading level0 col5" >CCSM4.SST</th>
#       <th id="T_c1682_level0_col6" class="col_heading level0 col6" >CanCM3.SST</th>
#       <th id="T_c1682_level0_col7" class="col_heading level0 col7" >CanCM4.SST</th>
#       <th id="T_c1682_level0_col8" class="col_heading level0 col8" >FLORB01.SST</th>
#       <th id="T_c1682_level0_col9" class="col_heading level0 col9" >FLORA06.SST</th>
#       <th id="T_c1682_level0_col10" class="col_heading level0 col10" >SPEAR.SST</th>
#       <th id="T_c1682_level0_col11" class="col_heading level0 col11" >SPEARb.SST</th>
#       <th id="T_c1682_level0_col12" class="col_heading level0 col12" >GEOSS2S.SST</th>
#       <th id="T_c1682_level0_col13" class="col_heading level0 col13" >CFSv2.SST</th>
#       <th id="T_c1682_level0_col14" class="col_heading level0 col14" >SPSv3p5.SST</th>
#       <th id="T_c1682_level0_col15" class="col_heading level0 col15" >SPSv3p0.SST</th>
#       <th id="T_c1682_level0_col16" class="col_heading level0 col16" >GCFS2p0.SST</th>
#       <th id="T_c1682_level0_col17" class="col_heading level0 col17" >GCFS2p1.SST</th>
#       <th id="T_c1682_level0_col18" class="col_heading level0 col18" >SEAS5.SST</th>
#       <th id="T_c1682_level0_col19" class="col_heading level0 col19" >SEAS51.SST</th>
#       <th id="T_c1682_level0_col20" class="col_heading level0 col20" >SEAS51b.SST</th>
#       <th id="T_c1682_level0_col21" class="col_heading level0 col21" >SEAS51c.SST</th>
#       <th id="T_c1682_level0_col22" class="col_heading level0 col22" >CPS2.SST</th>
#       <th id="T_c1682_level0_col23" class="col_heading level0 col23" >METEOFRANCE7.SST</th>
#       <th id="T_c1682_level0_col24" class="col_heading level0 col24" >METEOFRANCE8.SST</th>
#       <th id="T_c1682_level0_col25" class="col_heading level0 col25" >METEOFRANCE9.SST</th>
#       <th id="T_c1682_level0_col26" class="col_heading level0 col26" >GLOSEA5.SST</th>
#       <th id="T_c1682_level0_col27" class="col_heading level0 col27" >GLOSEA6.SST</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1682_level0_row0" class="row_heading level0 row0" >2026</th>
#       <td id="T_c1682_row0_col0" class="data row0 col0" >missing</td>
#       <td id="T_c1682_row0_col1" class="data row0 col1" >missing</td>
#       <td id="T_c1682_row0_col2" class="data row0 col2" >missing</td>
#       <td id="T_c1682_row0_col3" class="data row0 col3" >ok</td>
#       <td id="T_c1682_row0_col4" class="data row0 col4" >missing</td>
#       <td id="T_c1682_row0_col5" class="data row0 col5" >ok</td>
#       <td id="T_c1682_row0_col6" class="data row0 col6" >missing</td>
#       <td id="T_c1682_row0_col7" class="data row0 col7" >missing</td>
#       <td id="T_c1682_row0_col8" class="data row0 col8" >missing</td>
#       <td id="T_c1682_row0_col9" class="data row0 col9" >missing</td>
#       <td id="T_c1682_row0_col10" class="data row0 col10" >missing</td>
#       <td id="T_c1682_row0_col11" class="data row0 col11" >missing</td>
#       <td id="T_c1682_row0_col12" class="data row0 col12" >ok</td>
#       <td id="T_c1682_row0_col13" class="data row0 col13" >ok</td>
#       <td id="T_c1682_row0_col14" class="data row0 col14" >missing</td>
#       <td id="T_c1682_row0_col15" class="data row0 col15" >missing</td>
#       <td id="T_c1682_row0_col16" class="data row0 col16" >missing</td>
#       <td id="T_c1682_row0_col17" class="data row0 col17" >missing</td>
#       <td id="T_c1682_row0_col18" class="data row0 col18" >missing</td>
#       <td id="T_c1682_row0_col19" class="data row0 col19" >ok</td>
#       <td id="T_c1682_row0_col20" class="data row0 col20" >ok</td>
#       <td id="T_c1682_row0_col21" class="data row0 col21" >ok</td>
#       <td id="T_c1682_row0_col22" class="data row0 col22" >missing</td>
#       <td id="T_c1682_row0_col23" class="data row0 col23" >missing</td>
#       <td id="T_c1682_row0_col24" class="data row0 col24" >missing</td>
#       <td id="T_c1682_row0_col25" class="data row0 col25" >missing</td>
#       <td id="T_c1682_row0_col26" class="data row0 col26" >missing</td>
#       <td id="T_c1682_row0_col27" class="data row0 col27" >missing</td>
#     </tr>
#   </tbody>
# </table>
