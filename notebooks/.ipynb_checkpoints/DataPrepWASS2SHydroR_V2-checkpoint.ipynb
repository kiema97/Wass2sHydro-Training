# %% [markdown]
# <div style="width: 100%; text-align: center;">
#     <div style="background-color:#007F00; padding: 0.5rem;">
#         <h1 style="font-weight: bold; font-size: 2.5em; color: black;"> AGRHYMET CENTRE CLIMATIQUE REGIONAL POUR L'AFRIQUE DE L'OUEST ET LE SAHEL</h1>
#    </div>
#
#    <div style="text-align: center;">
#   <img src="https://www.sareco.org/wp-content/uploads/2017/07/plrDvYX1.jpg" width="200">
# </div>

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#FFFFFF ;margin:0;color:#007F00;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Capacity Building in Seasonal Hydrological Forecasting </p>

# %% [markdown]
# <a id="1"></a>
# ### <p style="padding:10px;background-color:#000000 ;margin:0;color:#007F00;font-family:#newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Data Prep for WASS2SHydroR </p>

# %% [markdown]
# "BEN" "GMB" "GHA" "GIN" "CIV" "LBR" "MLI" "MRT" "NER" "NGA" "GNB" "SEN" "SLE" "TGO" "BFA" "TCD" "CPV"

# %%
## Netoyage
setwd("D:/CCR_AOS/Wass2sHydro-Training")
rm(list = ls())
# ==== PARAMETERS (participants only edit this block) ==========================
COUNTRY_CODE <- "MLI" # "BEN" "GMB" "GHA" "GIN" "CIV" "LBR" "MLI" "MRT" "NER" "NGA" "GNB" "SEN" "SLE" "TGO" "BFA" "TCD" "CPV"
PREDICTOR_VARS <-"SST" # "PRCP", "SST"  # choose among available folders under predictors/
SELECTED_MODELS <- NULL  # e.g., c("CanCM3","CCSM4") or NULL to use all available
# Where things live (relative to project root)
PATH_COUNTRIES   <- "static/was_contries.shp"  # shapefile with GMI_CNTRY field
PATH_SUBBASINS   <- "static/subbassins.shp"     # shapefile with HYBAS_ID field
PATH_HISTORICAL  <- "data/was_subbassins_seasonal_data.csv" # columns: DATE, HYBAS_ID, Q, prcp, evap
PATH_PREDICTORS  <- "predictors"             # expect subfolders: PRCP/, SST/
PATH_OUTPUT <- "outputs"
# Optional: performance/speed knobs
N_CORES <- 4#max(1, parallel::detectCores() - 1)

# %%
#=========== Configuration files ===================================================
source("scripts/helpers_dp.R")
source("scripts/processing.R")
# Out:
# Warning message:
# "attribute variables are assumed to be spatially constant throughout all geometries"

# %% [markdown]
# ## 1) Select the user's country and find covered subbasins

# %%
# 1) Select the user's country and find covered subbasins
ggplot2::ggplot()+
  geom_sf(data=subs_sel)+
  geom_sf(data = country, fill="orange", alpha=0.2)+
  theme_minimal()+
  ggspatial::annotation_north_arrow(
    location = "tr",
    which_north = "true",
    style = north_arrow_fancy_orienteering,
    height = unit(1.2, "cm"),
    width = unit(1.2, "cm"),
    pad_x = unit(-0.1, "cm"),
    pad_y = unit(0.1, "cm")
  )+ ggspatial::annotation_scale(
    location = "br",
    width_hint = 0.3
  )
# Out:
# Scale on map varies by more than 10%, scale bar may be inaccurate
# plot without title

# %% [markdown]
# ## 2) Load historical data (HYPE-simulated Q) for selected subbasins

# %%
# 2) Load historical data for selected subbasins
hist_df <- readr::read_csv(PATH_HISTORICAL, show_col_types = FALSE) %>%
  #mutate(DATE = as.Date(.data$DATE)) %>%
  filter(.data$HYBAS_ID %in% HYBAS_IDS) %>%
  arrange(.data$HYBAS_ID, .data$DATE)

# Sanity check
hist_df %>% group_by(HYBAS_ID) %>% summarise(n = n(), .groups = "drop") %>% head(10)
# Out:
#    HYBAS_ID   n
# 1  1040023890 44
# 2  1040023950 44
# 3  1040040310 44
# 4  1040040380 44
# 5  1040040890 44
# 6  1040040960 44
# 7  1040041200 44
# 8  1040571730 44
# 9  1040633360 44
# 10 1040633540 44

# %%
## 3) Catalog available predictor files (PRCP / SST)

# %%
# 3) Catalog available predictor files (PRCP / SST)
pred_catalog <- catalog_predictors(base_dir = PATH_PREDICTORS,
                                   vars_keep = PREDICTOR_VARS) %>%
  dplyr::filter(init_year==2025)
unique(pred_catalog$model)
# Out:
#  [1] "CCSM4"        "CFSv2"        "CanSIPSIC4"   "GEOSS2S"      "METEOFRANCE9"
#  [6] "SEAS51"       "SEAS51b"      "SEAS51c"      "SPEARb"       "SPSv3p5"

# %%
# Filter by trainee choices
SELECTED_MODELS <- c("CCSM4","CFSv2","CanSIPSIC4","METEOFRANCE9",
                     "SEAS51","SPSv3p5","SEAS51c")

# %%
pred_catalog <- pred_catalog %>% filter(var %in% PREDICTOR_VARS)
if (!is.null(SELECTED_MODELS)) {
  pred_catalog <- pred_catalog %>% filter(model %in% SELECTED_MODELS)
}

# %%
training_list <- extract_predictors_nested(hybas_ids = unique(hist_df$HYBAS_ID),
                                           models = SELECTED_MODELS,
                                           hist_df = hist_df,
                                           predictor = PREDICTOR_VARS,
                                           predictors_root = PATH_PREDICTORS,
                                           subbasins_sf = subs_sel,
                                           init_year = 2025)
# Out:
# Processing bassin : 1040023890
#
# Processing bassin : 1040023950
#
# Processing bassin : 1040040310
#
# Processing bassin : 1040040380
#
# Processing bassin : 1040040890
#
# Processing bassin : 1040040960
#
# Processing bassin : 1040041200
#
# Processing bassin : 1040571730
#
# Processing bassin : 1040633360
#
# Processing bassin : 1040633540
#
# Processing bassin : 1040641660
#
# Processing bassin : 1040641670
#
# Processing bassin : 1040644790
#
# Processing bassin : 1040644920
#
# Processing bassin : 1040667360
#
# Processing bassin : 1040667560
#
# Processing bassin : 1040709030
#
# Processing bassin : 1040709280
#
# Processing bassin : 1040722570
#
# Processing bassin : 1040722720

# %% [markdown]
# ## 5) Quick sanity checks on the output list

# %%
## 5) Quick sanity checks on the output list
# Show first subbasin's head
training_list_clean <- training_list |>
  map(~ keep(.x, ~ is.data.frame(.x) && NROW(.x) > 0)) |>
  discard(~ length(.x) == 0)

first_key <- names(training_list)[1]
if (!is.null(first_key)) {
  training_list[[first_key]] %>% head()
}
# Out:
# $CCSM4
# # A tibble: 88 × 1,284
#      HYBAS_ID  YYYY     Q sst_1 sst_2 sst_3 sst_4 sst_5 sst_6 sst_7 sst_8 sst_9
#         <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl>
#  1 1040023890  1981  539.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  2 1040023890  1981  539.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  3 1040023890  1982  382.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  4 1040023890  1982  382.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  5 1040023890  1983  155.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  6 1040023890  1983  155.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  7 1040023890  1984  525.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  8 1040023890  1984  525.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  9 1040023890  1985  996.    NA    NA    NA    NA    NA    NA    NA    NA    NA
# 10 1040023890  1985  996.    NA    NA    NA    NA    NA    NA    NA    NA    NA
# # ℹ 78 more rows
# # ℹ 1,272 more variables: sst_10 <dbl>, sst_11 <dbl>, sst_12 <dbl>,
# #   sst_13 <dbl>, sst_14 <dbl>, sst_15 <dbl>, sst_16 <dbl>, sst_17 <dbl>,
# #   sst_18 <dbl>, sst_19 <dbl>, sst_20 <dbl>, sst_21 <dbl>, sst_22 <dbl>,
# #   sst_23 <dbl>, sst_24 <dbl>, sst_25 <dbl>, sst_26 <dbl>, sst_27 <dbl>,
# #   sst_28 <dbl>, sst_29 <dbl>, sst_30 <dbl>, sst_31 <dbl>, sst_32 <dbl>,
# #   sst_33 <dbl>, sst_34 <dbl>, sst_35 <dbl>, sst_36 <dbl>, sst_37 <dbl>, …
#
# $CFSv2
# # A tibble: 88 × 1,284
#      HYBAS_ID  YYYY     Q sst_1 sst_2 sst_3 sst_4 sst_5 sst_6 sst_7 sst_8 sst_9
#         <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl>
#  1 1040023890  1981  539.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  2 1040023890  1981  539.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  3 1040023890  1982  382.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  4 1040023890  1982  382.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  5 1040023890  1983  155.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  6 1040023890  1983  155.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  7 1040023890  1984  525.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  8 1040023890  1984  525.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  9 1040023890  1985  996.    NA    NA    NA    NA    NA    NA    NA    NA    NA
# 10 1040023890  1985  996.    NA    NA    NA    NA    NA    NA    NA    NA    NA
# # ℹ 78 more rows
# # ℹ 1,272 more variables: sst_10 <dbl>, sst_11 <dbl>, sst_12 <dbl>,
# #   sst_13 <dbl>, sst_14 <dbl>, sst_15 <dbl>, sst_16 <dbl>, sst_17 <dbl>,
# #   sst_18 <dbl>, sst_19 <dbl>, sst_20 <dbl>, sst_21 <dbl>, sst_22 <dbl>,
# #   sst_23 <dbl>, sst_24 <dbl>, sst_25 <dbl>, sst_26 <dbl>, sst_27 <dbl>,
# #   sst_28 <dbl>, sst_29 <dbl>, sst_30 <dbl>, sst_31 <dbl>, sst_32 <dbl>,
# #   sst_33 <dbl>, sst_34 <dbl>, sst_35 <dbl>, sst_36 <dbl>, sst_37 <dbl>, …
#
# $CanSIPSIC4
# # A tibble: 88 × 1,284
#      HYBAS_ID  YYYY     Q sst_1 sst_2 sst_3 sst_4 sst_5 sst_6 sst_7 sst_8 sst_9
#         <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl>
#  1 1040023890  1981  539.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  2 1040023890  1981  539.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  3 1040023890  1982  382.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  4 1040023890  1982  382.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  5 1040023890  1983  155.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  6 1040023890  1983  155.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  7 1040023890  1984  525.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  8 1040023890  1984  525.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  9 1040023890  1985  996.    NA    NA    NA    NA    NA    NA    NA    NA    NA
# 10 1040023890  1985  996.    NA    NA    NA    NA    NA    NA    NA    NA    NA
# # ℹ 78 more rows
# # ℹ 1,272 more variables: sst_10 <dbl>, sst_11 <dbl>, sst_12 <dbl>,
# #   sst_13 <dbl>, sst_14 <dbl>, sst_15 <dbl>, sst_16 <dbl>, sst_17 <dbl>,
# #   sst_18 <dbl>, sst_19 <dbl>, sst_20 <dbl>, sst_21 <dbl>, sst_22 <dbl>,
# #   sst_23 <dbl>, sst_24 <dbl>, sst_25 <dbl>, sst_26 <dbl>, sst_27 <dbl>,
# #   sst_28 <dbl>, sst_29 <dbl>, sst_30 <dbl>, sst_31 <dbl>, sst_32 <dbl>,
# #   sst_33 <dbl>, sst_34 <dbl>, sst_35 <dbl>, sst_36 <dbl>, sst_37 <dbl>, …
#
# $METEOFRANCE9
# # A tibble: 88 × 1,203
#      HYBAS_ID  YYYY     Q sst_1 sst_2 sst_3 sst_4 sst_5 sst_6 sst_7 sst_8 sst_9
#         <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl>
#  1 1040023890  1981  539.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  2 1040023890  1981  539.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  3 1040023890  1982  382.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  4 1040023890  1982  382.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  5 1040023890  1983  155.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  6 1040023890  1983  155.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  7 1040023890  1984  525.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  8 1040023890  1984  525.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  9 1040023890  1985  996.    NA    NA    NA    NA    NA    NA    NA    NA    NA
# 10 1040023890  1985  996.    NA    NA    NA    NA    NA    NA    NA    NA    NA
# # ℹ 78 more rows
# # ℹ 1,191 more variables: sst_10 <dbl>, sst_11 <dbl>, sst_12 <dbl>,
# #   sst_13 <dbl>, sst_14 <dbl>, sst_15 <dbl>, sst_16 <dbl>, sst_17 <dbl>,
# #   sst_18 <dbl>, sst_19 <dbl>, sst_20 <dbl>, sst_21 <dbl>, sst_22 <dbl>,
# #   sst_23 <dbl>, sst_24 <dbl>, sst_25 <dbl>, sst_26 <dbl>, sst_27 <dbl>,
# #   sst_28 <dbl>, sst_29 <dbl>, sst_30 <dbl>, sst_31 <dbl>, sst_32 <dbl>,
# #   sst_33 <dbl>, sst_34 <dbl>, sst_35 <dbl>, sst_36 <dbl>, sst_37 <dbl>, …
#
# $SEAS51
# # A tibble: 88 × 1,284
#      HYBAS_ID  YYYY     Q sst_1 sst_2 sst_3 sst_4 sst_5 sst_6 sst_7 sst_8 sst_9
#         <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl>
#  1 1040023890  1981  539.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  2 1040023890  1981  539.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  3 1040023890  1982  382.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  4 1040023890  1982  382.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  5 1040023890  1983  155.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  6 1040023890  1983  155.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  7 1040023890  1984  525.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  8 1040023890  1984  525.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  9 1040023890  1985  996.    NA    NA    NA    NA    NA    NA    NA    NA    NA
# 10 1040023890  1985  996.    NA    NA    NA    NA    NA    NA    NA    NA    NA
# # ℹ 78 more rows
# # ℹ 1,272 more variables: sst_10 <dbl>, sst_11 <dbl>, sst_12 <dbl>,
# #   sst_13 <dbl>, sst_14 <dbl>, sst_15 <dbl>, sst_16 <dbl>, sst_17 <dbl>,
# #   sst_18 <dbl>, sst_19 <dbl>, sst_20 <dbl>, sst_21 <dbl>, sst_22 <dbl>,
# #   sst_23 <dbl>, sst_24 <dbl>, sst_25 <dbl>, sst_26 <dbl>, sst_27 <dbl>,
# #   sst_28 <dbl>, sst_29 <dbl>, sst_30 <dbl>, sst_31 <dbl>, sst_32 <dbl>,
# #   sst_33 <dbl>, sst_34 <dbl>, sst_35 <dbl>, sst_36 <dbl>, sst_37 <dbl>, …
#
# $SPSv3p5
# # A tibble: 88 × 1,203
#      HYBAS_ID  YYYY     Q sst_1 sst_2 sst_3 sst_4 sst_5 sst_6 sst_7 sst_8 sst_9
#         <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl>
#  1 1040023890  1981  539.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  2 1040023890  1981  539.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  3 1040023890  1982  382.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  4 1040023890  1982  382.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  5 1040023890  1983  155.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  6 1040023890  1983  155.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  7 1040023890  1984  525.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  8 1040023890  1984  525.    NA    NA    NA    NA    NA    NA    NA    NA    NA
#  9 1040023890  1985  996.    NA    NA    NA    NA    NA    NA    NA    NA    NA
# 10 1040023890  1985  996.    NA    NA    NA    NA    NA    NA    NA    NA    NA
# # ℹ 78 more rows
# # ℹ 1,191 more variables: sst_10 <dbl>, sst_11 <dbl>, sst_12 <dbl>,
# #   sst_13 <dbl>, sst_14 <dbl>, sst_15 <dbl>, sst_16 <dbl>, sst_17 <dbl>,
# #   sst_18 <dbl>, sst_19 <dbl>, sst_20 <dbl>, sst_21 <dbl>, sst_22 <dbl>,
# #   sst_23 <dbl>, sst_24 <dbl>, sst_25 <dbl>, sst_26 <dbl>, sst_27 <dbl>,
# #   sst_28 <dbl>, sst_29 <dbl>, sst_30 <dbl>, sst_31 <dbl>, sst_32 <dbl>,
# #   sst_33 <dbl>, sst_34 <dbl>, sst_35 <dbl>, sst_36 <dbl>, sst_37 <dbl>, …

# %% [markdown]
# ## 6) Save the prepared list for modeling

# %%
## 6) Save the prepared list for modeling
dir.create(PATH_OUTPUT, showWarnings = FALSE)
savePath <- file.path(PATH_OUTPUT, paste0(PREDICTOR_VARS,"_training_list_", COUNTRY_CODE, ".rds"))
saveRDS(training_list_clean, file =savePath )
message("Saved: ",savePath)
# Out:
# Saved: outputs/training_list_BEN.rds
